# %%
import pandas as pd
south = pd.read_csv("south_pen-India_rainfall_act_dep_1901_2016.csv")
south.head()
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 155.8                 191.5                 138.4
# 1  1902                 118.9                 214.4                 159.7
# 2  1903                 141.0                 300.2                 206.2
# 3  1904                 191.9                 191.4                  89.5
# 4  1905                 153.5                 120.6                 187.6
#
#    Actual Rainfall: SEPT  Departure Percentage: JUN  \
# 0                  137.1                       -1.7
# 1                  193.7                      -25.3
# 2                  212.5                      -12.0
# 3                  130.6                       19.4
# 4                   99.0                       -4.0
#
#    Departure Percentage: JUL  Departure Percentage: AUG  \
# 0                      -10.1                      -18.5
# 1                        0.2                       -6.2
# ...

# %%
south.size
# Out:
# 1160

# %%
south[south['Actual Rainfall: JUN']==south['Actual Rainfall: JUN'].max()][['YEAR','Actual Rainfall: JUN']]
# Out:
#     YEAR  Actual Rainfall: JUN
# 90  1991                 278.0

# %%
central = pd.read_csv("central-India_rainfall_act_dep_1901_2016.csv")
ne = pd.read_csv("ne-India_rainfall_act_dep_1901_2016.csv")
nw = pd.read_csv("nw-India_rainfall_act_dep_1901_2016.csv")
central.head()
ne.head()
nw.head()
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                  22.7                 185.2                 264.1
# 1  1902                  59.9                 225.2                 143.8
# 2  1903                  26.2                 211.7                 275.2
# 3  1904                  53.4                 253.7                 234.0
# 4  1905                  23.1                 162.9                 128.3
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                   70.6                      542.7
# 1                  126.1                      555.1
# 2                  167.9                      680.9
# 3                   70.6                      611.7
# 4                  135.3                      449.6
#
#    Departure Percentage: JUN  Departure Percentage: JUL  \
# 0                      -67.2                      -21.5
# 1                      -13.0                       -3.8
# ...

# %%
south.nsmallest(5, 'YEAR')
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 155.8                 191.5                 138.4
# 1  1902                 118.9                 214.4                 159.7
# 2  1903                 141.0                 300.2                 206.2
# 3  1904                 191.9                 191.4                  89.5
# 4  1905                 153.5                 120.6                 187.6
#
#    Actual Rainfall: SEPT  Departure Percentage: JUN  \
# 0                  137.1                       -1.7
# 1                  193.7                      -25.3
# 2                  212.5                      -12.0
# 3                  130.6                       19.4
# 4                   99.0                       -4.0
#
#    Departure Percentage: JUL  Departure Percentage: AUG  \
# 0                      -10.1                      -18.5
# 1                        0.2                       -6.2
# ...

# %%
drysouth=south.sort_values(by='Departure Percentage: JUN-SEPT',ascending=True)
drysouth.head()
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17   1918                 114.4                  85.5                 123.7
# 101  2002                 151.7                  95.8                 182.0
# 51   1952                 131.1                 170.0                 150.0
# 4    1905                 153.5                 120.6                 187.6
# 71   1972                 147.8                 181.5                  92.6
#
#      Actual Rainfall: SEPT  Departure Percentage: JUN  \
# 17                   110.4                      -28.1
# 101                   77.2                       -8.0
# 51                    77.3                      -21.9
# 4                     99.0                       -4.0
# 71                   151.3                       -6.7
#
#      Departure Percentage: JUL  Departure Percentage: AUG  \
# 17                       -60.5                      -27.2
# 101                      -59.0                       -5.1
# ...

# %%
drycentral=central.sort_values(by='Departure Percentage: JUN-SEPT',ascending=True)
drycentral.head()
# Out:
#     YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17  1918                 199.7                 157.0                 238.8
# 86  1987                 103.3                 209.4                 259.7
# 73  1974                  90.2                 227.2                 285.9
# 71  1972                 116.0                 216.9                 297.2
# 19  1920                 147.3                 338.5                 176.2
#
#     Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 17                   84.4                      679.9
# 86                  111.2                      683.6
# 73                   99.9                      703.2
# 71                  124.9                      754.9
# 19                   98.1                      760.1
#
#     Departure Percentage: JUN  Departure Percentage: JUL  \
# 17                       18.1                      -55.4
# 86                      -33.0                      -37.7
# ...

# %%
dryne=ne.sort_values(by='Departure Percentage: JUN-SEPT',ascending=True)
dryne.head()
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 112  2013                 243.3                 288.5                 286.0
# 108  2009                 168.2                 305.0                 358.7
# 104  2005                 198.4                 347.8                 324.0
# 91   1992                 202.9                 361.0                 279.8
# 71   1972                 241.9                 333.6                 300.4
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 112                  227.7                     1045.5
# 108                  201.5                     1098.1
# 104                  173.5                     1043.7
# 91                   210.3                     1054.0
# 71                   230.4                     1106.3
#
#      Departure Percentage: JUN  Departure Percentage: JUL  \
# 112                      -30.5                      -33.9
# 108                      -49.1                      -24.5
# ...

# %%
drynw=nw.sort_values(by='Departure Percentage: JUN-SEPT',ascending=True)
drynw.head()
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17   1918                  68.8                  80.2                 164.9
# 86   1987                  56.0                  97.0                 146.3
# 78   1979                  52.5                 170.3                  99.3
# 108  2009                  35.8                 151.2                 124.0
# 64   1965                  22.1                 193.4                 129.5
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 17                    31.5                      345.4
# 86                    72.2                      371.4
# 78                    34.1                      356.2
# 108                   83.6                      394.6
# 64                    66.5                      411.5
#
#      Departure Percentage: JUN  Departure Percentage: JUL  \
# 17                         0.5                      -65.2
# 86                       -19.3                      -57.7
# ...

# %%
region=input('Enter the region:')
month=input('Enter the month:')
if(region=='south'):
    print('true')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
from pandas import DataFrame
df = pd.read_excel('METEOROLOGICAL_SUB_DIVISION_WISE_ANNUAL_RAINFALL.xls')
df.head()
# Out:
#                            Sub-division  2002 (in millimetre)  \
# 0           Andaman and Nicobar Islands                2310.7
# 1                     Arunachal Pradesh                2559.6
# 2                   Assam and Meghalaya                2530.4
# 3  Nagaland,Mizoram,Manipur and Tripura                1960.8
# 4   Sub-Himalayan,West Bengal & Sikkim                 2820.1
#
#    2003 (in millimetre)  2004 (in millimetre)  2005 (in millimetre)  \
# 0                2446.9                2508.1                2762.6
# 1                2761.2                2891.7                2542.4
# 2                2835.1                2890.9                2314.8
# 3                2029.0                1999.3                1612.4
# 4                3288.5                2768.3                2670.8
#
#    2006 (in millimetre)  2007 (in millimetre)  2008 (in millimetre)    \
# 0                2447.9                2656.7                  3335.2
# ...
